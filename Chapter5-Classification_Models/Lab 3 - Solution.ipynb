# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data_url = "https://github.com/fenago/tf/raw/main/Chapter5-Classification_Models/datasets/faults.csv"

data = pd.read_csv(data_url, sep=",")
data.head()
# Out:
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0         42       50.0     270900     270944           267           17
# 1        645      651.0    2538079    2538108           108           10
# 2        829      835.0    1553913    1553931            71            8
# 3        853      860.0     369370     369415           176           13
# 4       1289     1306.0     498078     498335          2409           60
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0           44              24220                     76
# 1           30              11397                     84
# 2           19               7972                     99
# 3           45              18996                     99
# 4          260             246930                     37
#
#    Maximum_of_Luminosity  ...  Edges_X_Index  Edges_Y_Index  \
# 0                    108  ...         0.4706         1.0000
# 1                    123  ...         0.6000         0.9667
# 2                    125  ...         0.7500         0.9474
# 3                    126  ...         0.5385         1.0000
# 4                    126  ...         0.2833         0.9885
#
#    Outside_Global_Index  LogOfAreas  Log_X_Index  Log_Y_Index  \
# 0                   1.0      2.4265       0.9031       1.6435
# 1                   1.0      2.0334       0.7782       1.4624
# 2                   1.0      1.8513       0.7782       1.2553
# 3                   1.0      2.2455       0.8451       1.6532
# 4                   1.0      3.3818       1.2305       2.4099
#
#    Orientation_Index  Luminosity_Index  SigmoidOfAreas  target
# 0             0.8182           -0.2913          0.5822  Pastry
# 1             0.7931           -0.1756          0.2984  Pastry
# 2             0.6667           -0.1228          0.2150  Pastry
# 3             0.8444           -0.1568          0.5212  Pastry
# 4             0.9338           -0.1992          1.0000  Pastry
#
# [5 rows x 28 columns]

# %%
data['target'].value_counts()
# Out:
# target
# Other_Faults    673
# Bumps           402
# K_Scatch        391
# Z_Scratch       190
# Pastry          158
# Stains           72
# Dirtiness        55
# Name: count, dtype: int64

# %%
data['target'].value_counts()
# Out:
# target
# Other_Faults    673
# Bumps           402
# K_Scatch        391
# Z_Scratch       190
# Pastry          158
# Stains           72
# Dirtiness        55
# Name: count, dtype: int64

# %%
reduce_map = {"target": {'Pastry':0, 'Z_Scratch':1, 'K_Scatch':2, 'Stains':3, 'Dirtiness':4, 'Bumps':5,
       'Other_Faults':6} }
data.replace(reduce_map, inplace=True)
# Out:
# <ipython-input-5-a7da2a3ddf49>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace(reduce_map, inplace=True)

# %%
data['target'].value_counts()
# Out:
# target
# 6    673
# 5    402
# 2    391
# 1    190
# 0    158
# 3     72
# 4     55
# Name: count, dtype: int64

# %%
data.dropna(inplace=True)

# %%
y = data.pop('target')
X = data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,
                                                  stratify=y,random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1308, 27)
# (561, 27)
# (1308,)
# (561,)

# %%
y_train.head()
# Out:
# 459     2
# 787     3
# 1134    5
# 1270    6
# 704     2
# Name: target, dtype: int64

# %%
import tensorflow as tf

# %%
tf.random.set_seed(8)

# %%
model = tf.keras.Sequential()

# %%
from tensorflow.keras.layers import Dense

# %%
fc1 = Dense(512, input_shape=(27,), activation='relu')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
fc2 = Dense(512, activation='relu')

# %%
fc3 = Dense(128, activation='relu')

# %%
fc4 = Dense(128, activation='relu')

# %%
fc5 = Dense(7, activation='softmax')

# %%
model.add(fc1)
model.add(fc2)
model.add(fc3)
model.add(fc4)
model.add(fc5)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 512)                 │          14,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          65,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 7)                   │             903 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 360,071 (1.37 MB)
#  Trainable params: 360,071 (1.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
loss = tf.keras.losses.SparseCategoricalCrossentropy()

# %%
optimizer = tf.keras.optimizers.Adam(0.001)

# %%
model.compile(optimizer=optimizer, loss=loss, \
                  metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2311 - loss: 64930.1406
# Epoch 2/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3421 - loss: 15837.9092
# Epoch 3/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3324 - loss: 7027.7100
# Epoch 4/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3308 - loss: 5526.4517
# Epoch 5/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3128 - loss: 3203.9041
# Epoch 6/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3103 - loss: 1753.4255
# Epoch 7/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3014 - loss: 1304.8169
# Epoch 8/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2879 - loss: 1833.2572
# Epoch 9/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3000 - loss: 742.8743
# Epoch 10/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3446 - loss: 943.6475
# Epoch 11/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3144 - loss: 642.1240
# Epoch 12/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3270 - loss: 479.0850
# Epoch 13/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3073 - loss: 685.9930
# Epoch 14/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2872 - loss: 811.5580
# Epoch 15/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3325 - loss: 402.8842
# Epoch 16/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2999 - loss: 468.7056
# Epoch 17/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3335 - loss: 878.9379
# Epoch 18/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3349 - loss: 322.2961
# Epoch 19/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3099 - loss: 345.3666
# Epoch 20/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4113 - loss: 37.8428
# Epoch 21/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3907 - loss: 22.8269
# Epoch 22/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3949 - loss: 13.3250
# Epoch 23/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3993 - loss: 5.6925
# Epoch 24/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3958 - loss: 4.0468
# Epoch 25/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3911 - loss: 6.2355
# Epoch 26/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3874 - loss: 3.7761
# Epoch 27/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3918 - loss: 7.1295
# Epoch 28/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3895 - loss: 4.5744
# Epoch 29/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3972 - loss: 10.1556
# Epoch 30/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3854 - loss: 2.6733
# Epoch 31/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3944 - loss: 3.9477
# Epoch 32/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3900 - loss: 3.9216
# Epoch 33/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3938 - loss: 4.3954
# Epoch 34/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3923 - loss: 6.0382
# Epoch 35/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3901 - loss: 9.6157
# Epoch 36/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3958 - loss: 3.7387
# Epoch 37/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4021 - loss: 4.3960
# Epoch 38/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3837 - loss: 6.1068
# Epoch 39/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3689 - loss: 2.0389
# Epoch 40/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3717 - loss: 1.8417
# Epoch 41/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3662 - loss: 1.7757
# Epoch 42/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3599 - loss: 1.7686
# Epoch 43/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3581 - loss: 1.6838
# Epoch 44/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3575 - loss: 1.7125
# Epoch 45/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3580 - loss: 1.6793
# Epoch 46/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3578 - loss: 1.6690
# Epoch 47/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3584 - loss: 1.6779
# Epoch 48/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3574 - loss: 1.6693
# Epoch 49/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3579 - loss: 1.6717
# Epoch 50/50
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3573 - loss: 1.6669

# %%
model.evaluate(X_test, y_test)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3424 - loss: 1.6625
# [1.644606590270996, 0.3582887649536133]
