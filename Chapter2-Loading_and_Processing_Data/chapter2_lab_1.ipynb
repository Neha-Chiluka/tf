# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/fenago/tf/main/Chapter4-Regression_and_Classification_Models/dataset/Summary_of_Weather.csv"


df = pd.read_csv(url)

# %%
df.head()
# Out:
#      STA        Date    MaxTemp    MinTemp   MeanTemp  Snowfall  YR  MO  DA  \
# 0  10001  01-07-1942  25.555556  22.222222  23.888889       0.0  42   7   1
# 1  10001  02-07-1942  28.888889  21.666667  25.555556       0.0  42   7   2
# 2  10001  03-07-1942  26.111111  22.222222  24.444444       0.0  42   7   3
# 3  10001  04-07-1942  26.666667  22.222222  24.444444       0.0  42   7   4
# 4  10001  05-07-1942  26.666667  21.666667  24.444444       0.0  42   7   5
#
#     MAX   MIN   MEA
# 0  78.0  72.0  75.0
# 1  84.0  71.0  78.0
# 2  79.0  72.0  76.0
# 3  80.0  72.0  76.0
# 4  80.0  71.0  76.0

# %%
df.drop("Date", inplace=True, axis=1)

# %%
ax = df['MaxTemp'].hist(color='gray', bins = 20)
ax.set_xlabel("MaxTemp")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
from sklearn.preprocessing import StandardScaler
df1 = df.loc[:, ['MaxTemp', 'MinTemp', 'MeanTemp']]
scaler = StandardScaler() # Create an instance of StandardScaler
df2 = scaler.fit_transform(df1)
df2 = pd.DataFrame(df2, columns=['MaxTemp', 'MinTemp', 'MeanTemp'])
df2.head()
# Out:
#     MaxTemp   MinTemp  MeanTemp
# 0 -0.170864  0.531849  0.178027
# 1  0.211496  0.465192  0.378880
# 2 -0.107137  0.531849  0.244978
# 3 -0.043411  0.531849  0.244978
# 4 -0.043411  0.465192  0.244978

# %%
ax = df2['MaxTemp'].hist(color='gray')
ax.set_xlabel("Normalized Temperature")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')
