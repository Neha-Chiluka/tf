# %%
from google.colab import files


# Step 2: Unzip the file (replace 'your_file.zip' with the actual file name)
# !unzip -q /content/dataset.zip -d /content/

# Step 3: Verify the extracted content
# !ls /content/
# Out:
# dataset  dataset.zip  sample_data

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory('dataset/image_data/',\
                    target_size = (64, 64),\
                    batch_size = 25,\
                    class_mode = 'binary')
# Out:
# Found 15 images belonging to 2 classes.

# %%
import matplotlib.pyplot as plt
def show_batch(image_batch, label_batch):
    lookup = {v: k for k, v in training_set.class_indices.items()}
    label_batch = [lookup[label] for label in label_batch]
    plt.figure(figsize=(10,10))
    for n in range(15):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        plt.title(label_batch[n].title())
        plt.axis('off')

# %%
image_batch, label_batch = next(training_set)
show_batch(image_batch, label_batch)
